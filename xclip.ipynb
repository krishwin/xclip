# %%
# %rm -r ./xclip
# Out:
# rm: cannot remove './xclip': No such file or directory

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
pat = user_secrets.get_secret("pat")

# %%
USER = "krishnawin"
CLONE_URL = f"https://{USER}:{pat}@github.com/{USER}/xclip.git"
get_ipython().system(f"git clone {CLONE_URL}")
# Out:
# Cloning into 'xclip'...
# remote: Enumerating objects: 148, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 148 (delta 60), reused 121 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (148/148), 1.49 MiB | 17.35 MiB/s, done.
# Resolving deltas: 100% (60/60), done.

# %%
# %cp -r /kaggle/input/fitness-xclip/data ./xclip

# %%
# !pip install mmcv==2.2.0 -f https://download.openmmlab.com/mmcv/dist/cu121/torch2.4/index.html
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.4/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.3/452.3 kB 7.7 MB/s eta 0:00:00
# ...

# %%
# !pip install -r ./xclip/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 84.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 3.0 MB/s eta 0:00:00
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
module_path = os.path.abspath(os.path.join('./xclip'))
sys.path.insert(0, module_path)

# %%
# !python -m torch.distributed.launch --nproc_per_node=2 ./xclip/main.py -cfg ./xclip/configs/fit101/16_8.yaml --output ./ --accumulation-steps 4
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/distributed/launch.py:208: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use-env is set by default in torchrun.
# If your script expects `--local-rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   main()
# W1023 06:14:57.570000 139513614337856 torch/distributed/run.py:779]
# W1023 06:14:57.570000 139513614337856 torch/distributed/run.py:779] *****************************************
# W1023 06:14:57.570000 139513614337856 torch/distributed/run.py:779] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# ...

# %%
ls -lrt
# Out:
# total 10470360
# drwxr-xr-x 11 root root       4096 Oct 23 06:14 xclip/
# -rw-r--r--  1 root root        395 Oct 23 06:15 16_8.yaml
# -rw-r--r--  1 root root  779890679 Oct 23 06:15 ckpt_epoch_0.pth
# -rw-r--r--  1 root root  779858815 Oct 23 06:15 best.pth
# -rw-r--r--  1 root root 1832151092 Oct 23 06:19 ckpt_epoch_10.pth
# -rw-r--r--  1 root root 1832151092 Oct 23 06:22 ckpt_epoch_20.pth
# -rw-r--r--  1 root root 1832151092 Oct 23 06:26 ckpt_epoch_30.pth
# -rw-r--r--  1 root root 1832151092 Oct 23 06:30 ckpt_epoch_40.pth
# -rw-r--r--  1 root root 1832151092 Oct 23 06:33 ckpt_epoch_49.pth
# -rw-r--r--  1 root root      40103 Oct 23 06:33 log_rank1.txt
# -rw-r--r--  1 root root      41991 Oct 23 06:33 log_rank0.txt
# ----------  1 root root     998128 Oct 23 06:33 __notebook__.ipynb
